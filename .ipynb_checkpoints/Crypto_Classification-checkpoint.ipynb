# %%
import pandas as pd

# %%
#Read crypto_data.csv into Pandas. The dataset was obtained from CryptoCompare.


crypto_df = pd.read_csv("crypto_data.csv")

crypto_df
# Out:
#      Unnamed: 0        CoinName Algorithm  IsTrading ProofType  \
# 0            42         42 Coin    Scrypt       True   PoW/PoS
# 1           365         365Coin       X11       True   PoW/PoS
# 2           404         404Coin    Scrypt       True   PoW/PoS
# 3           611       SixEleven   SHA-256       True       PoW
# 4           808             808   SHA-256       True   PoW/PoS
# ...         ...             ...       ...        ...       ...
# 1247        XBC     BitcoinPlus    Scrypt       True       PoS
# 1248       DVTC      DivotyCoin    Scrypt      False   PoW/PoS
# 1249       GIOT     Giotto Coin    Scrypt      False   PoW/PoS
# 1250       OPSC  OpenSourceCoin   SHA-256      False   PoW/PoS
# 1251       PUNK       SteamPunk       PoS      False       PoS
#
#       TotalCoinsMined TotalCoinSupply
# 0        4.199995e+01              42
# 1                 NaN      2300000000
# 2        1.055185e+09       532000000
# 3                 NaN          611000
# 4        0.000000e+00               0
# ...               ...             ...
# 1247     1.283270e+05         1000000
# 1248     2.149121e+07       100000000
# 1249              NaN       233100000
# 1250              NaN        21000000
# 1251              NaN        40000000
#
# [1252 rows x 7 columns]

# %%
#filter out crypto that is no linger being traded
crypto_clean = crypto_df[crypto_df["IsTrading"] == True]



# crypto_clean[""]

# %%
#drop the Istrading column
crypto_clean1 = crypto_clean.drop("IsTrading", axis=1)

# %%
crypto_clean2 = crypto_clean1.dropna()

# %%
crypto_clean3 = crypto_clean2.loc[crypto_clean["TotalCoinsMined"] > 0]

# %%
crypto_clean4 = crypto_clean3.drop("CoinName", axis=1)

# %%
crypto_clean
# Out:
#      Unnamed: 0     CoinName    Algorithm  IsTrading ProofType  \
# 0            42      42 Coin       Scrypt       True   PoW/PoS
# 1           365      365Coin          X11       True   PoW/PoS
# 2           404      404Coin       Scrypt       True   PoW/PoS
# 3           611    SixEleven      SHA-256       True       PoW
# 4           808          808      SHA-256       True   PoW/PoS
# ...         ...          ...          ...        ...       ...
# 1243       SERO   Super Zero       Ethash       True       PoW
# 1244        UOS          UOS      SHA-256       True      DPoI
# 1245        BDX       Beldex  CryptoNight       True       PoW
# 1246        ZEN      Horizen     Equihash       True       PoW
# 1247        XBC  BitcoinPlus       Scrypt       True       PoS
#
#       TotalCoinsMined TotalCoinSupply
# 0        4.199995e+01              42
# 1                 NaN      2300000000
# 2        1.055185e+09       532000000
# 3                 NaN          611000
# 4        0.000000e+00               0
# ...               ...             ...
# 1243              NaN      1000000000
# 1244              NaN      1000000000
# 1245     9.802226e+08      1400222610
# 1246     7.296538e+06        21000000
# 1247     1.283270e+05         1000000
#
# [1144 rows x 7 columns]

# %%
# crypto_clean = pd.get_dummies(crypto_clean)

crypto_clean5 = crypto_clean4.drop("Unnamed: 0", axis=1)
crypto_clean
# Out:
#      Unnamed: 0     CoinName    Algorithm  IsTrading ProofType  \
# 0            42      42 Coin       Scrypt       True   PoW/PoS
# 1           365      365Coin          X11       True   PoW/PoS
# 2           404      404Coin       Scrypt       True   PoW/PoS
# 3           611    SixEleven      SHA-256       True       PoW
# 4           808          808      SHA-256       True   PoW/PoS
# ...         ...          ...          ...        ...       ...
# 1243       SERO   Super Zero       Ethash       True       PoW
# 1244        UOS          UOS      SHA-256       True      DPoI
# 1245        BDX       Beldex  CryptoNight       True       PoW
# 1246        ZEN      Horizen     Equihash       True       PoW
# 1247        XBC  BitcoinPlus       Scrypt       True       PoS
#
#       TotalCoinsMined TotalCoinSupply
# 0        4.199995e+01              42
# 1                 NaN      2300000000
# 2        1.055185e+09       532000000
# 3                 NaN          611000
# 4        0.000000e+00               0
# ...               ...             ...
# 1243              NaN      1000000000
# 1244              NaN      1000000000
# 1245     9.802226e+08      1400222610
# 1246     7.296538e+06        21000000
# 1247     1.283270e+05         1000000
#
# [1144 rows x 7 columns]

# %%
crypto_clean6 = crypto_clean5["TotalCoinSupply"] = pd.to_numeric(crypto_clean5["TotalCoinSupply"])

# crypto_clean = pd.get_dummies(crypto_clean)

# crypto_clean

# for column in crypto_clean.columns:
#     print(column)

crypto_clean6.info
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/qt/z1139kj16rq91qs03f19sz2c0000gn/T/ipykernel_29574/1467667148.py in <module>
#       8 #     print(column)
#       9
# ---> 10 crypto_clean6.info
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'info'

# %%
pd.get_dummies(crypto_clean6)
# Out:
#       0.000000e+00  4.200000e+01  1.000000e+03  1.200000e+05  2.500000e+05  \
# 0                0             1             0             0             0
# 2                0             0             0             0             0
# 5                0             0             0             0             0
# 7                0             0             0             0             0
# 8                1             0             0             0             0
# ...            ...           ...           ...           ...           ...
# 1238             0             0             0             0             0
# 1242             0             0             0             0             0
# 1245             0             0             0             0             0
# 1246             0             0             0             0             0
# 1247             0             0             0             0             0
#
#       5.000000e+05  6.164480e+05  6.194780e+05  1.000000e+06  1.350000e+06  \
# 0                0             0             0             0             0
# 2                0             0             0             0             0
# 5                0             0             0             0             0
# 7                0             0             0             0             0
# 8                0             0             0             0             0
# ...            ...           ...           ...           ...           ...
# 1238             0             0             0             0             0
# 1242             0             0             0             0             0
# 1245             0             0             0             0             0
# 1246             0             0             0             0             0
# 1247             0             0             0             1             0
#
#       ...  9.900000e+10  1.000000e+11  1.840000e+11  1.844674e+11  \
# 0     ...             0             0             0             0
# 2     ...             0             0             0             0
# 5     ...             0             0             0             0
# 7     ...             0             0             0             0
# 8     ...             0             0             0             0
# ...   ...           ...           ...           ...           ...
# 1238  ...             0             0             0             0
# 1242  ...             0             0             0             0
# 1245  ...             0             0             0             0
# 1246  ...             0             0             0             0
# 1247  ...             0             0             0             0
#
#       1.844700e+11  2.000000e+11  3.141593e+11  3.840000e+11  9.900000e+11  \
# 0                0             0             0             0             0
# 2                0             0             0             0             0
# 5                0             0             1             0             0
# 7                0             0             0             0             0
# 8                0             0             0             0             0
# ...            ...           ...           ...           ...           ...
# 1238             0             0             0             0             0
# 1242             0             0             0             0             0
# 1245             0             0             0             0             0
# 1246             0             0             0             0             0
# 1247             0             0             0             0             0
#
#       1.000000e+12
# 0                0
# 2                0
# 5                0
# 7                0
# 8                0
# ...            ...
# 1238             0
# 1242             0
# 1245             0
# 1246             0
# 1247             0
#
# [532 rows x 276 columns]
